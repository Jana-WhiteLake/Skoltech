# %% [markdown]
# ### Homework 11
#
# ### Jane Beloozerova
#
# Problems: 4.3-1, 4.3-6, 4.3-13, 4.5-2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ R_A = \frac{800*3}{4}+\frac{1600*1}{4} = 1000 \text{ lb} $$
#
# $$ R_B = \frac{800*1}{4}+\frac{1600*3}{4} = 1400 \text{ lb} $$
#
# $$ V = 1600 - 1400 = 200 \text{ lb} $$
#
# $$ M = 1400 * 30 = 42000 \text{ lb-in}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ P_1 = 4.0 \text{kN} \quad P_2 = 8.0 \text{kN} $$
#
# $$ R_A = 1.0 \text{kN} \quad R_B = 9.0 \text{kN} $$
#
# $$ V = -R_A = -1.0 \text{kN} $$
#
# $$ M = -1.0*3.0 - 4.0 = - 7.0 m $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ q_1 = 3500 \text{ lb/ft} $$
#
# $$ q_2 = \frac{8}{14}q_1 = 2000 \text{ lb/ft} $$
#
# a) At point  B:
#
# $$V = 6000 \text{ lb} \quad M = 9000 \text{ lb-ft}$$
#
# b) At midpoint:
#
# $$ V_{mp} = 2000*7.0 - 3500*4.0 = 0 $$
#
# $$ M_{mp} = 2000*7.0*3.5 - 3500*4.0*2.0 = 21000 \text{ lb/ft} $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
