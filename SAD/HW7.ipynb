# %% [markdown]
# ### Homework #7
#
# ### Jane Beloozerova
#
# Problems 8.2-2, 8.2-4, 8.3-2, 8.3-5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ p = 3.5 MPa \quad d = 18 m \quad \sigma_y = 550 MPa \quad FS_y = 3.0 $$
#
# $$ \sigma_a = \frac{\sigma_y}{FS_y} = 183.33 MPa $$
#
# $$ t = \frac{p*d/2}{2\sigma_a} = 86 mm $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ p = 60 kPa \quad d = 230 mm \quad t = 1.2 mm \quad E = 3.5 MPa \nu = 0.45 $$
#
# $$ \sigma_{max} = \frac{p*d/2}{2t} = 2.875 MPa $$

# %% [markdown]
# $$ \epsilon_{max} = \frac{pd/2}{2tE}(1-\nu) =  0.45 $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ d = 2.0 m = 2000 mm \quad t = 18 mm $$
#
# a)
#
# $$ \sigma = 10.9 MPa $$
#
# $$ \gamma = 9.81 kN/m^3 $$
#
# $$ \sigma = \frac{pr}{t} = \frac{\gamma h d/2}{t} \quad => \quad h = \frac{2\sigma t}{\gamma d} = 20 m $$

# %% [markdown]
# b) Axial stress equals zero, because the top of the tank is open.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ r/t = 200 \quad  \epsilon_0 = 170*10^{-6} \quad E = 10*10^6 psi \quad \nu = 0.33 $$
#
# $$ p = \frac{2\epsilon_0 E}{r/t(1-2\nu)} = 50 psi $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ od_1 = 400 mm \quad id_1 = 240 mm $$
#
# $$ od_2 = 240 mm \quad id_2 = 140 mm $$
#
# $$ => b = 240 mm, \quad a = 140 mm, \quad c = 400 mm $$
#
# $$ \delta = 0.3 mm \quad E = 200 GPa \quad \nu = 0.3 $$
#
# $$ p_i = \frac{E\delta}{b}[\frac{(c^2-b^2)(b^2-a^2)}{2b^2(c^2-a^2)}] = 60,1 MPa $$

# %% [markdown]
# ![image.png](attachment:image.png)
