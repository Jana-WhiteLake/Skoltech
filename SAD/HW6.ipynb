# %% [markdown]
# ### Homework #6
#
# ### Jane Beloozerova
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ P_{max} = \frac{4 \sigma_a t}{2} = 0.4 MPa $$
#
# $$r = 0.5m \quad => \quad d = 1 m $$
#
# $$ \sigma_a = \frac{\sigma_y}{FS_y} \quad FS_y = 3 $$
#
# $$ => \sigma_a = \frac{300*10^6}{3} = 100 MPa $$
#
# $$ => t = \frac{P_{max} d}{4 \sigma_a} = \frac{0.4*10^6*1}{4*100*10^6} = 1 * 10^{-3} m $$
