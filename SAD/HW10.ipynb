# %% [markdown]
# ### Homework 10
#
# ### Jane Beloozerova
#
# Problems: 3.2-1, 3.3-5, 3.4-9, 3.10-1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution
#
# $$ L = 18.0 in \quad \theta = 3.0^o \quad \gamma_{allow} = 0.0006 $$
#
# $$ \theta = 3.0^o = 0.05236 rad $$
#
# $$ \gamma = \frac{d\theta}{2L} \quad => \quad d = \frac{2L\gamma}{\theta} = 0.41 in $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ d = 0.5 in \quad \tau_{allow} = 40 ksi \quad G = 11,600 ksi \quad \theta = 30^o = 0.52360 rad $$
#
# $$ \tau_{max} = \frac{16T}{\pi d^3} $$
#
# $$ \theta = \frac{TL}{GI} = \frac{TL}{G \frac{\pi d^4}{32}} \quad => \quad T = \frac{G\pi d^4 \theta}{32L} $$
#
# $$ => \tau_{max} = \frac{Gd\theta}{2L} \quad => \quad L_{min} = \frac{Gd\theta}{2\tau_{allow}} = 38 in $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ T = 36,000 \text{ lb-in} \quad L = 4.0 ft \quad G = 3.9*10^6 psi \quad  \tau_{allow} = 15,000 psi \quad \theta_{allow} = 3.0^o = 0.05236 \text{ rad} \quad \beta = 1.5  $$

# %% [markdown]
# $$ \tau = \frac {16T}{\pi d_A^3} \quad => \quad d_A = \sqrt[3]{\frac {16T}{\pi \tau_{allow}}} = 2.3 in $$

# %% [markdown]
# $$ \theta = \frac{TL}{GI}(\frac{\beta^2+\beta +1}{3\beta^2})= \frac{TL}{G \frac{\pi d^4}{32}}(\frac{\beta^2+\beta +1}{3\beta^2}) \quad => \quad d_A = \sqrt[4]{\frac{32LT}{G\pi\theta_{allow}}(\frac{\beta^2+\beta +1}{3\beta^2})} = 2.52 in $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ d_{in} = 10.0 in \quad t = 1.0 in \quad T = 1200 \text{k-in}$$
#
# a) $$ d_{out} = 12.0 in \quad d_{av} = \frac{d_{out} - d_{in}}{2}$$
#
# $$ \tau = \frac{T}{2\pi \frac{d_{av}^2}{4}t} = 6310 psi $$
#
# b) $$ \tau = \frac {Td_{out}/2}{\frac{\pi (d_{out}^4-d_{in}^4)}{32}} = 6830 psi $$
