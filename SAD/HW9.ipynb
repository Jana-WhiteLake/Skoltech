# %% [markdown]
# ### Homework #9
#
# ### Jane Beloozerova
#
# Problems  2.11-1, 2.11-2, 2.12-2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ \epsilon = \frac{\sigma}{E}+\frac{\sigma_0 \alpha}{E}(\frac{\sigma}{\sigma_0})^m = \frac{\gamma x}{E}+\frac{\sigma_0 \alpha}{E}(\frac{\gamma x}{\sigma_0})^m $$
#
# $$ \sigma = \gamma x $$
#
# $$ \delta = \int_0^L \epsilon dx = \int_0^L \frac{\gamma x}{E} dx + \frac{\sigma_0 \alpha}{E}\int_0^L (\frac{\gamma x}{\sigma_0})^m dx = \frac{\gamma L^2}{2E}  + \frac{\sigma_0 \alpha L}{(m+1)E}(\frac{\gamma L}{\sigma_0})^m $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution
#
# $$ L = 1.8 m \quad A = 480 mm^2 \quad P_1 = 30 kN \quad P_2 = 60 kN $$
#
# $$ \epsilon = \frac{\sigma}{45,000} + \frac{1}{618}(\frac{\sigma}{170})^{10} \quad (\sigma = MPa) $$

# %% [markdown]
# a) $$ \sigma = \frac{P_1}{A} = \frac{30 \text{kN}}{480 \text{mm}^2} = 62.5 MPa $$
#
# $$ \epsilon = \frac{\sigma}{45,000} + \frac{1}{618}(\frac{\sigma}{170})^{10} = 0.00139 $$
#
# $$ \delta_C = \epsilon (\frac{2L}{3}) = 1.67 mm $$

# %% [markdown]
# b) $$ \sigma = \frac{P_2}{A} = \frac{60 \text{kN}}{480 \text{mm}^2} = 125 MPa $$
#
# $$ \epsilon = \frac{\sigma}{45,000} + \frac{1}{618}(\frac{\sigma}{170})^{10} = 0.00285 $$
#
# $$ \delta_C = \epsilon L = 5.13 mm $$

# %% [markdown]
# с)
#
# AB: $$\sigma_1 = \frac{P_1 + P_2}{A} = \frac{90 \text{kN}}{480 \text{mm}^2} = 187.5 MPa $$
#
# $$ \epsilon_1 = \frac{\sigma_1}{45,000} + \frac{1}{618}(\frac{\sigma_1}{170})^{10} = 0.00848 $$
#
# $$ \delta_{AB} = \epsilon_1 (\frac{2L}{3}) = 10.17 mm $$
#
# BC: $$\sigma_2 = \frac{P_2}{A} = \frac{90 \text{kN}}{480 \text{mm}^2} = 125 MPa $$
#
# $$ \epsilon_2 = \frac{\sigma_2}{45,000} + \frac{1}{618}(\frac{\sigma_2}{170})^{10} = 0.00285 $$
#
# $$ \delta_{BC} = \epsilon_2 (\frac{L}{3}) = 1.71 mm $$
#
# $$ \delta_C = \delta_{AB} + \delta_{BC} = 11.88 mm $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution
#
# $$ d_1 = 20 mm \quad d_2 = 25 mm \quad \sigma_Y = 250 MPa $$
#
# $$ P_C = F_{AC} + F_{BC} = \sigma_Y A_1 + \sigma_Y A_2 = \frac{\sigma_Y \pi}{4} (d_1^2 + d_2^2) = 201 kN $$
