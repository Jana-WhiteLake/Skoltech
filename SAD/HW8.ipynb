# %% [markdown]
# ### Homework #8
#
# ### Jane Beloozerova
#
# Problems 2.2-2, 2.2-11, 2.3-3, 2.4-8, 2.5-1, 2.8-8

# %% [markdown]
# 2.2-2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ d = 25 mm \quad W = 38 kN \quad E = 140 GPa $$
#
# ![image.png](attachment:image.png)
#
# a) $$L = 14 m \quad A = 304 mm^2$$
#
# $$\delta = \frac{WL}{EA} = 12.5 mm $$
#
# b) $$ P_{max} = 70 kN $$
#
# $$ P = 406 kN $$
#
# $$ => n = \frac{P}{P_{max}} = 5.8 kN $$

# %% [markdown]
# 2.2-11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$E = 30000 ksi \quad L = 8.0 ft \quad d = 7.5 in \quad P = 85 k $$
#
# $$ \sigma_{allow} = 7000 psi \quad  \delta_{allow} = 0.02 in $$
#
# $$ A = \frac{P}{\sigma_{allow}} = 12.14 in^2 $$
#
# On the other side
#
# $$ A = \frac{PL}{E\delta_{allow}} = 13.6 in^2 - \text{it is }A_{min}$$
#
# $$ A = \frac{\pi}{4}(d^2 - (d - 2t)^2) $$
#
# $$ => t_{min} = \frac{d}{2} - \sqrt{(\frac{d}{2})^2-\frac{A_{min}}{\pi}} = 0.63 in $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ A = 0.40 in^2 \quad P_1 = 2700 lb \quad P_2 = 1800 lb \quad P_3 = 1300 lb $$
#
# $$ a = 60 in \quad b = 24 in \quad c = 36 in $$
#
# a) $$ E = 30 * 10^6 psi $$
#
# $$\delta = \frac{N_1*L_1}{E*A} + \frac{N_2*L_2}{E*A} + \frac{N_3*L_3}{E*A} $$
#
# $$ N_1 = P_1 + P_2 - P_3 = 3200 lb $$
#
# $$ N_2 = P_2 - P_3 = 500 lb $$
#
# $$ N_3 = - P_3 = -1300 lb $$
#
# $$ => \delta = 0.013 in $$
#
# b) $$ P = \frac{\delta EA}{L} = 1310 lb $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ A_1 = 840 mm^2 \quad L_1 = 200 mm \quad A_2 = 1260 mm^2 \quad L_2 = 250 mm $$
#
# $$ P_B = 25.5 kN \quad P_C = 17.0 kN $$
#
# a) $$ P_B - P_C = R_A - R_D = 8.5 kN $$
#
# $$ \delta_{AD} = \delta_{AB} + \delta_{BC} + \delta_{CD} = 0 $$
#
# $$ \delta_{AB} = \frac{R_AL_1}{EA_1} $$
#
# $$ \delta_{BC} = \frac{(R_A-P_B)L_2}{EA_2} $$
#
# $$ \delta_{CD} = \frac{R_DL_1}{EA_1} $$
#
# $$ \delta_{AD} = \frac{R_AL_1}{EA_1} + \frac{R_AL_2}{EA_2} - \frac{P_BL_2}{EA_2} + \frac{R_DL_1}{EA_1} = 0 $$

# %% [markdown]
# $$ 0.24R_A + 0.2R_A +0.24R_D = 5 kN $$
#
# $$ 0.44 R_A + 0.24 R_D = 5 kN $$
#
# $$ R_A - R_D = 8.5 kN \quad => \quad R_A = 8.5 + R_D $$
#
# $$ 3.7 + 0.68 R_D = 5 \quad => \quad R_D = 1.9 kN \quad => \quad R_A = 10.4 kN $$

# %% [markdown]
# b) $$ F_{BC} = P_B - R_A = P_C - R_D = 15.1 kN $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ T_2 = 120^o \quad T_1 = 60^o \quad => \quad \Delta T = T_2 - T_1 = 60^o $$
#
# $$ \alpha = 6.5*10^{-6} F$$
#
# $$ E = 30 * 10^{6} psi $$
#
# $$ \sigma = \alpha E \Delta T = 11700 psi $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
# $$ A = 40 mm^2 \quad E = 130 GPa \quad M = 35 kg \quad h = 1.0 m \quad \sigma_{allow} = 500 MPa $$
#
# $$ \sigma_{max} = \sigma_{st} [1 + (1 + \frac{2hE}{L_{min}\sigma_{st}})^{\frac{1}{2}}] $$

# %% [markdown]
# $$ => \quad L_{min} = \frac{2hE\sigma_{st}}{\sigma_{max}(\sigma_{max}-2\sigma_{st})} $$

# %% [markdown]
# $$ \sigma_{st} = \frac{W}{A} = \frac{Mg}{A} = 8.6 MPa $$
#
# $$ => \quad L_{min} = 9.25 mm $$
