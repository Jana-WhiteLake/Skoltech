# %% [markdown]
# ### Homework 12
#
# ### Jane Beloozerova
#
# Problems: 5.4-1, 5.4-5, 5.5-4, 5.8-10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ R = 24 \text{ in} \quad d = \frac{1}{16} \text{ in} $$
#
# $$ \epsilon_{max} = \frac{y}{p} = \frac{d}{2R+d} = 1300*10^{-6}  $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ L = 20 \text{ in} \quad t = 0.2 \text{ in} \quad \delta = 0.25 \text{ in} $$
#
# $$ \epsilon = \frac{y}{p} = \frac{t/2}{p} $$
#
# $$ \delta = p - p*\cos\theta$$
#
# $$ \theta \approx \sin \theta = \frac{L/2}{p} $$
#
# $$ => \delta = p - p*\cos(\frac{L/2}{p}) \quad => \quad p = 200 \text{ in} \quad => \quad \epsilon = 500*10^{-6} $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ L = 3.5 \text { m} \quad q = 6.4 \text{ kN/m} \quad b = 140 \text {mm} \quad h = 240 \text { mm} $$
#
# $$ \sigma_{max} = \frac{M_{max}}{S} = \frac{3qL^2}{4bh^2} = 7.29 \text{ MPa}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution:
#
# $$ L = 1.2 m \quad w = 140 mm \quad h = 240 mm \quad \gamma = 5.4 kN/m^3 $$
#
# a) $$\sigma_{allow} = 8.5 MPa $$
#
# $$ \sigma = \frac{M_{max}}{S} $$
#
# $$ M_{max} = S\sigma_{allow} = [S=\frac{wh^2}{6}=1344*10^3 mm^3] = 11420 N*m $$
#
# $$ M_{max} = \frac{PL}{4} + {qL^2}{8} = 11420 N*m \quad => \quad P = 38 kN $$
#
# b) $$ \tau_{allow} = 0.8 MPa $$
#
# $$ \tau = \frac{3V}{2A} \quad => \quad V = \frac{2A\tau}{3} = 17920 N $$
#
# $$ V = \frac{P}{2}+\frac{qL}{2} = 17920 N \quad => \quad P = 35.6 kN $$
#
# $$ => P_{allow} = 35.6 kN $$
