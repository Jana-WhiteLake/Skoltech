# %%
import math

# %% [markdown]
# ### Homework #1
#
# ### Jane Beloozerova
#
# Problems 1.2-1, 1.2-3 and 1.2-4

# %% [markdown]
# 1.2-1
# ![image.png](attachment:image.png)

# %%
P1 = 2500
d_ab = 1.25
d_bc = 2.25

# %%
sigma = round(P1/(math.pi*d_ab**2/4),-1)
print ("a) sigma =", sigma)
P2 = round(sigma * math.pi *(d_bc)**2/4 - P1, -1)
print ("b) P2 =", P2)
# Out:
# a) sigma = 2040.0
# b) P2 = 5610.0

# %% [markdown]
# a) $$ \sigma_{AB} = \frac{P_1}{A} = \frac {P_1}{\pi d_{AB}^2/4} = 2040 psi $$
# b) $$ \sigma_{BC} = \frac{P_1+P_2}{A} => P_2 = \sigma_{BC}A-P_1 = \sigma_{BC}\pi d_{BC}^2/4 - P_1 = 5610 lb$$

# %% [markdown]
# 1.2-3
# ![image.png](attachment:image.png)

# %% [markdown]
# Density of steel is $490 lb/ft^3$
#
# It should be noted that $1 ft^2 = 144 in^2$

# %%
L = 110
d = 0.25
W = 200
gamma = 490
sigma_max = round((W+(math.pi*d**2/4)*(L/144)*gamma)/(math.pi*d**2/4),-1)
print ("sigma_max =", sigma_max)
# Out:
# sigma_max = 4450.0

# %% [markdown]
# $$ W_0 = \gamma V = \gamma AL$$
#
# $$ \sigma_{max} = \frac{F_{max}}{A} = \frac{W + \gamma \frac{A}{144}L}{A} = 4450 psi $$

# %% [markdown]
# 1.2-4
# ![image.png](attachment:image.png)

# %%
L = 400
d_out = 60
d_in = 50
epsilon = 550*10**(-6)
sigma = 40

# %%
delta = round(epsilon*L,2)
print ("delta =", delta)
P = round(sigma*(math.pi*(d_out**2-d_in**2)/4),-2)
print ("P =", P)
# Out:
# delta = 0.22
# P = 34600.0

# %% [markdown]
# a) $$ \delta = \epsilon L = 0.22 mm $$
# b) $$ \sigma = \frac{P}{A} => P = \sigma A = \sigma \frac{\pi (d_{out}^2-d_{in}^2)}{4} = 34600 N = 34.6 kN$$
