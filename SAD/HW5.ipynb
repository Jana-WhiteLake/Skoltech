# %% [markdown]
# ### Homework #5
#
# #### Jane Beloozerova
#
# Problems 7.5-2, 7.5-3, 7.6-1, 7.6-3, 7.6-10.

# %% [markdown]
# #### Problem 7.5-2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ t = 10 mm,\quad \epsilon_x = 480 * 10^{-6},\quad \epsilon_y = 130 * 10^{-6}$$
#
# $$ E = 200 GPa, \quad \nu = 0.30 $$

# %% [markdown]
# $$ \sigma_x = \frac{E}{(1-\nu^2)}(\epsilon_x+\nu \epsilon_y) = 114.1 MPa $$
#
# $$ \sigma_y = \frac{E}{(1-\nu^2)}(\epsilon_y+\nu \epsilon_x) = 60.2 MPa $$

# %% [markdown]
# $$ \epsilon_z = - \frac{\nu}{E} (\sigma_x + \sigma_y) = -261.4 * 10^{-6} $$

# %% [markdown]
# $$ \Delta t = \epsilon_z t = -2610*10^{-6} mm $$

# %% [markdown]
# #### Problem 7.5-3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# a) $$ \sigma_x = \frac{E}{(1-\nu^2)}(\epsilon_x+\nu \epsilon_y) $$
#
# $$ \sigma_y = \frac{E}{(1-\nu^2)}(\epsilon_y+\nu \epsilon_x) $$
#
# $$ \epsilon_z = - \frac{\nu}{E} (\sigma_x + \sigma_y) $$

# %% [markdown]
# $$ => \epsilon_z = - \frac{\nu}{1-\nu} (\epsilon_x + \epsilon_y) $$

# %% [markdown]
# b) $$ e = \frac{1 - 2\nu}{E}  (\sigma_x + \sigma_y) $$
#
# $$ => e = \frac{1 - 2\nu}{1 - \nu}  (\epsilon_x + \epsilon_y) $$

# %% [markdown]
# #### Problem 7.6-1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ \sigma_x = 12,000 psi, \quad \sigma_y = -4,000 psi, \quad \sigma_z = -1,000 psi $$

# %% [markdown]
# $$ a = 6.0 in, \quad b = 4.0 in, \quad c = 3.0 in $$

# %% [markdown]
# $$ E = 10400 ksi \quad \nu = 0.33 $$

# %% [markdown]
# a) $$ \tau_{max} = \frac{\sigma_1 - \sigma_3}{2} = 8000 psi $$

# %% [markdown]
# b) $$ \epsilon_x = - \frac{\sigma_x}{E} - \frac{\nu}{E} (\sigma_y + \sigma_z) = 1312.5 * 10^{-6} $$
#
# $$ \epsilon_y = - \frac{\sigma_y}{E} - \frac{\nu}{E} (\sigma_z + \sigma_x) = -733.7 * 10^{-6} $$
#
# $$ \epsilon_z = - \frac{\sigma_z}{E} - \frac{\nu}{E} (\sigma_x + \sigma_y) = -350.0 * 10^{-6} $$

# %% [markdown]
# $$ \Delta a = a\epsilon_x = 0.0079 in $$
#
# $$ \Delta b = b\epsilon_y = -0.0029 in $$
#
# $$ \Delta c = c\epsilon_z = -0.0011 in $$

# %% [markdown]
# c) $$ e = \frac{1 - 2\nu}{E}  (\sigma_x + \sigma_y + \sigma_z) = 228.8 * 10^{-6} $$

# %% [markdown]
# $$ \Delta V = e*a*b*c = 0.0165 in^{3} $$

# %% [markdown]
# d) $$ u = \frac{1}{2} (\sigma_x \epsilon_x + \sigma_y \epsilon_y + \sigma_z \epsilon_z) = 9.157 psi $$

# %% [markdown]
# $$ U = u*a*b*c = 685 $$

# %% [markdown]
# #### Problem 7.6-3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ \epsilon_x = -225 * 10^{-6},\quad \epsilon_y = \epsilon_z = -37.5 * 10^{-6}$$

# %% [markdown]
# $$ E = 14000 ksi \quad \nu = 0.25 $$

# %% [markdown]
# $$ a = 4.0 in $$

# %% [markdown]
# a) $$ \sigma_x = \frac{E}{(1+\nu)(1-\nu)}((1-\nu)\epsilon_x+\nu (\epsilon_y+\epsilon_z)) = -4200 psi $$
#
# $$ \sigma_y = \frac{E}{(1+\nu)(1-\nu)}((1-\nu)\epsilon_y+\nu (\epsilon_z+\epsilon_x)) = -2100 psi $$
#
# $$ \sigma_z = \frac{E}{(1+\nu)(1-\nu)}((1-\nu)\epsilon_z+\nu (\epsilon_x+\epsilon_y)) = -2100 psi $$

# %% [markdown]
# b) $$ \tau_{max} = \frac{\sigma_x - \sigma_z}{2} = 1050 psi $$

# %% [markdown]
# с) $$ e = \epsilon_x + \epsilon_y + \epsilon_z = -3*10^{-4} $$
#
# $$ \Delta V = ea^3 = -0.0192 in^3 $$

# %% [markdown]
# d) $$ u = \frac{1}{2} (\sigma_x \epsilon_x + \sigma_y \epsilon_y + \sigma_z \epsilon_z) = 0.55125 psi $$
#
# $$ U = u*a^3 = 35.3 J $$

# %% [markdown]
# #### Problem 7.6-10
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ E = 210 GPa, \quad \nu = 0.3 $$

# %% [markdown]
# a) $$ e = \frac{3\sigma_0 (1-2\nu)}{E} \quad => \quad p = \sigma_0 = \frac{Ee}{3(1-2\nu)} = 700 MPa $$

# %% [markdown]
# b) $$ K = \frac{\sigma_0}{E} = \frac{700 * 10^6}{4*10^{-3}} = 175 GPa $$

# %% [markdown]
# c) $$d = 150 mm $$

# %% [markdown]
# $$ u = \frac{3(1-2\nu)\sigma_0^2}{2E} = 1.4 MPa $$
#
# $$ V_0 = \frac{4 \pi r^3}{3} = 1767 * 10^{-6} m^3 $$
#
# $$ U = uV_0 = 2470 J $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ \varepsilon_a = 1100 \mu\varepsilon, \quad \varepsilon_b = 1500 \mu\varepsilon, \quad \varepsilon_c = -50 \mu\varepsilon $$

# %% [markdown]
# $$ E = 70 GPa, \quad \nu = 0.33 $$

# %% [markdown]
# $$ \theta = 0^o:  \varepsilon_a = 1100 \mu\varepsilon$$
#
# $$ \theta = 30^o:  \varepsilon_b = 1500 \mu\varepsilon$$
#
# $$ \theta = 150^o:  \varepsilon_c = -50 \mu\varepsilon$$

# %% [markdown]
# $$ \varepsilon_x = \varepsilon_A = 1100 * 10^{-6} $$
#
# For $ \theta = 30^o $
#
# $$ \varepsilon_{x_1} = \frac{\varepsilon_x + \varepsilon_y}{2} + \frac{\varepsilon_x - \varepsilon_y}{2} \cos 2\theta + \frac{\gamma_{xy}}{2} \sin 2\theta = \varepsilon_b = 1500 * 10^{-6} $$
#
# $$ => \varepsilon_y + \sqrt{3} \gamma_{xy} = 2700 $$
#
# For $ \theta = 150^o $
#
# $$ \varepsilon_{x_1} = \frac{\varepsilon_x + \varepsilon_y}{2} + \frac{\varepsilon_x - \varepsilon_y}{2} \cos 2\theta + \frac{\gamma_{xy}}{2} \sin 2\theta = \varepsilon_b = -50 * 10^{-6} $$
#
# $$ => \varepsilon_y - \sqrt{3} \gamma_{xy} = -3500 $$

# %% [markdown]
# $$ => \varepsilon_y = -400*10^{-6} $$
#
# $$ => \gamma_{xy} = 1789,8 * 10^{-6} $$

# %% [markdown]
# $$ \sigma_x = \frac{E}{(1-\nu^2)}(\varepsilon_x+\nu \varepsilon_y) = 76.04 MPa $$
